# %% [markdown]
# ## Note
# - Author: Luke Arunanondchai
# - Last version: 1/30/2019
# - This version: 1/30/2019
# - Changes since last version:
# 	- None
#
# - Software: Python 3.7
# - Purpose of Work: Scrape the bold auditing words from 'https://www.ais-cpa.com/glosa/'
# - Project: ARM

# %% [markdown]
# #### Load all the necessary packages

# %%
from pandas import DataFrame
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup

# %% [markdown]
# #### Basic functions for importing the html -

# %%
# Attempts to get the content at `url` by making an HTTP GET request.
def simple_get(url):
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None

# Returns True if the response seems to be HTML, False otherwise.
def is_good_response(resp):
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)

# Keep log for errors (if any)
def log_error(e):
    print(e)

# %% [markdown]
# ### ** Input Here **

# %%
url = 'https://www.ais-cpa.com/glosa'

# %%
raw_html = simple_get(url)
html = BeautifulSoup(raw_html, 'html.parser')

# Create an empty list to collect all the auditing words
auditing = []

# Collecting words
for i, s in enumerate(html.select('strong')):
    auditing.append(s.text)

df1 = DataFrame(auditing, columns = ['Word'])

# %%
df1
# Out:
#                                          Word
# 0                        acceptance sampling
# 1             accounting and review services
# 2                            accounting data
# 3                        accounting estimate
# 4                       accounting principles
# 5                         accounts receivable
# 6                          accounting records
# 7              accounting research bulletins
# 8                           adjusting entries
# 9                                     adverse
# 10                          advisory services
# 11                     aggregate (aggregated)
# 12                     agreed-upon procedures
# 13                                      aicpa
# 14                                 allocation
# 15            allowance for doubtful accounts
# 16                allowance for sampling risk
# 17                       analytical procedure
# 18                                    analyze
# 19                                anticipated
# 20                              apb opinions
# 21   applicable financial reporting framework
# 22                        application control
# 23                                appropriate
# 24                                   approve
# 25                  arm’s length transactions
# 26                                  ascertain
# 27                                  assertion
# 28                                    assess
# 29                                   assessed
# ..                                        ...
# 365             those charged with governance
# 366                               tick marks
# 367                    times interest earned
# 368                   timing of audit testing
# 369                  tolerable deviation rate
# 370                   tolerable misstatement
# 371                                     trace
# 372                                 treasurer
# 373                           treasury stock
# 374                            trend analysis
# 375                            trial balance
# 376                                  turnover
# 377                unconditional requirements
# 378                 uncorrected misstatements
# 379                              unqualified
# 380                          update (updated)
# 381                              user auditor
# 382                            validity check
# 383                                 valuation
# 384                       value-added network
# 385                        variable sampling
# 386                                  variance
# 387                                   vendors
# 388                    verify (verification)
# 389                                    vouch
# 390                                   voucher
# 391                      webtrust engagements
# 392                            working papers
# 393                                write-off
# 394                                  write-up
#
# [395 rows x 1 columns]

# %% [markdown]
# ### Exporting the words

# %%
df1.to_excel('../output/fromWeb.xlsx')
